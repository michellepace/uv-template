# %% [markdown]
# # Test Notebook Setup
#
# This notebook verifies that the Jupyter setup is working correctly:
#
# 1. Test we can import our project code (`uv_template` package)
# 2. Then test we can run that code by calling the `add()` function
# 3. Make sure we can do regular notebook things like using Plotly

# %%
# (1) Import from the project package
from uv_template.play import add

# (2) Test the add function
result = add(5, 15)
print("🙂 🙂 🙂 ")
print(f"Testing add(5, 15) = {result}")
assert result == 20, "add() function should return 12"
print("✓ Project code import successful!")

# %%
# (3) Test Plotly Express rendering
import plotly.express as px
import pandas as pd

# Create sample data
df = pd.DataFrame(
    {"x": [1, 2, 3, 4, 5], "y": [2, 4, 5, 7, 8], "category": ["A", "B", "A", "B", "A"]}
)

# Create an interactive scatter plot
fig = px.scatter(
    df,
    x="x",
    y="y",
    color="category",
    title="Test Plotly Express Graph",
    labels={"x": "X Axis", "y": "Y Axis"},
)

fig.show()
print("🦚🍑")
print("✓ Plotly rendering successful!")

# %% [markdown]
# ## Success!
#
# If you can see:
# - ✓ Project code imports working
# - ✓ Interactive Plotly graph displayed above
#
# Then your Jupyter setup is fully functional and ready for the AI Agents course! 🎉
